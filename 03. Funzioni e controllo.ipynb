# %% [markdown]
# # Creazione di Funzioni in Python
#
# In questo notebook esploreremo come creare e utilizzare funzioni in Python, inclusi costrutti come `if`, cicli, argomenti predefiniti, argomenti variabili e funzioni anonime.
#
# ---

# %% [markdown]
# ## Indice
#
# 1. [La Clausola `if`](#sezione1)
# 2. [Cicli su Serie di Dati](#sezione2)
# 3. [Creare Funzioni Personalizzate](#sezione3)
# 4. [Argomenti Predefiniti](#sezione4)
# 5. [Argomenti Variabili (`*args` e `**kwargs`)](#sezione5)
# 6. [Funzioni Lambda e Tecniche Avanzate](#sezione6)
# 7. [Esercizi](#sezione7)
#
# ---

# %% [markdown]
# <a id='sezione1'></a>
# ## 1. La Clausola `if`
#
# La clausola `if` permette di eseguire un blocco di codice solo se una certa condizione è vera.
#
# ### Sintassi Base
#
# ```python
# if condizione:
#     # Codice da eseguire se la condizione è vera
# ```
#
# ### Uso di `else`
#
# Per specificare un blocco di codice alternativo quando la condizione è falsa:
#
# ```python
# if condizione:
#     # Codice se la condizione è vera
# else:
#     # Codice se la condizione è falsa
# ```
#
# ### Annidamento di `if`
#
# È possibile annidare più clausole `if` per gestire condizioni più complesse:
#
# ```python
# if condizione1:
#     if condizione2:
#         # Codice se entrambe le condizioni sono vere
#     else:
#         # Codice se condizione1 è vera ma condizione2 è falsa
# else:
#     # Codice se condizione1 è falsa
# ```
#
# ### Esempi

# %%
x = 4
x % 2 == 0

# %%
condizione_pari = x % 2 == 0

if condizione_pari:
    print('numero pari!')

# %%
# Esempio 1: Clausola if semplice
x = 1
if x > 5:
    print("x è maggiore di 5")
else:
    print("x è minore o uguale a 5")

# %%
# Esempio 2: Clausola if annidata
x = 9
if x > 5:
    if x > 8:
        print("x è maggiore di 5 e anche maggiore di 8")
else:
    print("x è minore o uguale a 5")

# %%
True or False

# %%
# Esempio 3: Clausola if con più condizioni
x = 10
y = 12
if x > 5 and y > 10:
    print("x è maggiore di 5 e y è maggiore di 10")
else:
    print("Almeno una delle due condizioni non è soddisfatta")

# %% [markdown]
# ---
#
# <a id='sezione2'></a>
# ## 2. Cicli su Serie di Dati
#
# I cicli permettono di eseguire un blocco di codice ripetutamente su elementi di una sequenza come liste o tuple.
#
# ### Ciclo `for`
#
# Esempio di iterazione su una lista:

# %%
lista = [1, 2, 3, 4, 5]
for elemento in lista:
    print(elemento)

# %% [markdown]
# Utilizzo del ciclo `for` con una condizione `if`:

# %%
for num in lista:
    if num % 2 == 0:
        print(f"Il numero {num} è pari.")
    else:
        print(f"Il numero {num} è dispari.")

# %% [markdown]
# E se volessimo fare il loop solo su una parte degli elementi?

# %%
# esempio loop su sotto insieme 
for num in lista[1::2]:
    if num % 2 == 0:
        print(f"Il numero {num} è pari.")
    else:
        print(f"Il numero {num} è dispari.")

# %% [markdown]
# ### 📘 Accesso ai Dati in un Dizionario
#
# #### Visualizzare Chiavi e Valori con `.items()`
# Il metodo `.items()` permette di ottenere tutte le coppie chiave-valore di un dizionario come una lista di tuple.

# %%
dizionario = {'nome': 'Marco', 'cognome': 'Rossi', 'età': 30}

dizionario.items()

# %% [markdown]
# #### Accedere a Chiavi e Valori con un Ciclo `for`
# Utilizzando `.items()` insieme a un ciclo `for`, è possibile iterare su tutte le coppie chiave-valore di un dizionario:

# %%
dizionario = {'nome': 'Marco', 'cognome': 'Rossi', 'età': 30}

for k, v in dizionario.items():
    print(k, ' : ',v)

# %% [markdown]
# #### Usare `enumerate()` per Ottenere Indice ed Elemento
#
# La funzione `enumerate()` permette di iterare su una lista mantenendo il conteggio degli elementi. Specificando `start=1`, è possibile far iniziare il conteggio da 1 invece di 0.

# %%
days = ['lunedì', 'martedì','mercoledì']

for idx, day in enumerate(days, start=1):
    print(idx, day)

# %% [markdown]
# #### Iterare su Due Liste Contemporaneamente
#
# La funzione `zip()` permette di iterare su due liste in parallelo, combinando i loro elementi in coppie. In questo esempio, controlliamo le condizioni meteo per identificare i giorni soleggiati.

# %%
days = ['lunedì', 'martedì','mercoledì']
weather_list = ['sole', 'pioggia','sole']
sunny_days = []

for day, weather in zip(days, weather_list):
    if weather == 'sole':
        #print(f'Oggi è {day} ed è soleggiato!')
        sunny_days.append(day)

print(f'I giorni di sole sono stati: {sunny_days}')

# %% [markdown]
# ### 🔄 Ripetere un'Azione con `range()`
#
# #### Ciclo `for` con un Numero Fisso di Iterazioni
#
# Utilizzando `range(n_iter)`, è possibile eseguire un'azione un numero specifico di volte. In questo esempio, stampiamo "ciao" 10 volte.

# %%
n_iter = 10

for i in range(n_iter):
    print('ciao\n')

# %% [markdown]
# ### 🔄 Iterabili, Iteratori e Generatori in Python: Concetti di Base
#
# Quando si lavora con Python, è utile comprendere i concetti di **iterabili**, **iteratori** e **generatori**, che rendono possibile l’uso di cicli `for` e consentono di gestire grandi quantità di dati in modo efficiente.
#
# #### Iterabili
#
# Un **iterabile** è qualsiasi oggetto che contiene una sequenza di elementi e che può essere percorso, come liste, stringhe e dizionari. Sono detti "iterabili" perché ci permettono di attraversare i loro elementi uno alla volta in un ciclo `for`.
#
# #### Iteratori
#
# Un **iteratore** è un oggetto che produce gli elementi di un iterabile uno alla volta. Python crea un iteratore ogni volta che si usa un ciclo `for`. Gli iteratori utilizzano il metodo `next()` per restituire l'elemento successivo; se non ci sono più elementi, sollevano l'eccezione `StopIteration`.
#
# #### Riepilogo
#
# - Un **iterabile** è un oggetto che può essere attraversato, come liste e stringhe.
# - Un **iteratore** restituisce un elemento alla volta da un iterabile.

# %% [markdown]
# ### Ciclo `while`
#
# Il ciclo `while` esegue il blocco di codice finché una condizione è vera:

# %%
x = 0
while x < 5:
    print(x)
    x += 1

# %% [markdown]
# ---
#
# <a id='sezione3'></a>
# ## 3. Creare Funzioni Personalizzate
#
# Le funzioni consentono di incapsulare codice riutilizzabile.
#
# ### Definizione di una Funzione
#
# ```python
# def nome_funzione(parametri):
#     # Corpo della funzione
#     return risultato
# ```
#
# ### Esempio

# %%
def somma(a, b):
    return a + b

risultato = somma(2, 3)
print(risultato)  # Output: 5

# %% [markdown]
# ### Argomenti Keyword
#
# È possibile specificare gli argomenti usando il nome dei parametri:

# %%
def messaggio(nome, testo):
    print(f"Ciao {nome}, {testo}")
    
messaggio(testo="come stai?", nome="Paolo")
# Output: Ciao Paolo, come stai?

# %% [markdown]
# ---
#
# <a id='sezione4'></a>
# ## 4. Argomenti Predefiniti
#
# È possibile definire valori predefiniti per i parametri:

# %%
def saluta(nome="Marco"):
    print(f"Ciao {nome}")

saluta()           # Output: Ciao Marco
saluta("Paolo")    # Output: Ciao Paolo

# %%
days = ['lunedì', 'martedì','mercoledì']
weather_list = ['sole', 'pioggia','sole']
sunny_days = []

for day, weather in zip(days, weather_list):
    if weather == 'sole':
        #print(f'Oggi è {day} ed è soleggiato!')
        sunny_days.append(day)

print(f'I giorni di sole sono stati: {sunny_days}')

# %%
def sunny_fun(days, weather_list, annuncio = False):
    """
    Funzione che restutuisce i giorni di sole
    """
    sunny_days = []
    for day, weather in zip(days, weather_list):
        if weather == 'sole': 
            if annuncio : print(f'Oggi è {day} ed è soleggiato!')
            sunny_days.append(day)

    return sunny_days

# %%
days = ['lunedì', 'martedì','mercoledì']
weather_list = ['sole', 'pioggia','sole']

sunny_fun(days, weather_list=weather_list, annuncio=True)

# %% [markdown]
# <a id='sezione6'></a>
# ## 6. Funzioni Lambda e Tecniche Avanzate
#
# ### Funzioni Lambda
#
# Le funzioni lambda sono funzioni anonime e compatte:

# %%
quadrato = lambda x: x ** 2
print(quadrato(4))  # Output: 16

# %% [markdown]
# ### List Comprehension
#
# Sintassi compatta per creare liste:

# %%
squares = [x ** 2 for x in range(1, 11)]
print(squares)

# %% [markdown]
# ### Funzione `map`
#
# Applica una funzione a tutti gli elementi di una lista:

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x ** 2, numbers))
print(squared_numbers)

# %% [markdown]
# ### Funzione `filter`
#
# Filtra elementi in base a una condizione:

# %%
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)

# %% [markdown]
# Questi strumenti permettono di scrivere codice più conciso ed efficiente.
#
# ---

# %% [markdown]
# <a id='sezione7'></a>
# ## 7. Esercizi
#
# ### Esercizio 1
#
# Scrivi una funzione che prenda in input una stringa e restituisca la stringa invertita.
#
# 💡 **Hint:** puoi pensare alla stringa come una **lista** di caratteri.
#
#
# **Esempio:**
#
# - Input: `'Python'`
# - Output: `'nohtyP'`

# %%
def reverse_string...
    return ...

# %%
assert reverse_string("Python") == "nohtyP", "❌ Stringa invertita errata"
print("✅ Stringa invertita correttamente")

# %% [markdown]
# ### Esercizio 2
#
# Scrivi una funzione che prenda in input un dizionario di paesi e capitali e restituisca la lista dei paesi la cui capitale ha un numero pari di lettere.
#
# **Esempio:**
#
# ```python
# g10 = {
#     'Canada': 'Ottawa',
#     'Francia': 'Parigi',
#     'Germania': 'Berlino',
#     'Italia': 'Roma',
#     'Giappone': 'Tokyo',
#     'Regno Unito': 'Londra',
#     'Stati Uniti': 'Washington',
#     'Spagna': 'Madrid',
#     'Paesi Bassi': 'Amsterdam',
#     'Corea del Sud': 'Seoul'
# }
# ```
#
# **Output atteso:**
#
# Lista dei paesi con capitale di lunghezza pari.

# %%
def paesi_capitale_pari(dizionario):
    # inizializza una lista vuota chiamata result
    ...
    
    for paese, capitale ... # loop su chiave, valore (usa .items())
        if ...: # condizione lunghezza pari del nome della capitale
            result... # aggiungi a result il paese visto che la condizione è rispettata
    return result

g10 = {
    'Canada': 'Ottawa',
    'Francia': 'Parigi',
    'Germania': 'Berlino',
    'Italia': 'Roma',
    'Giappone': 'Tokyo',
    'Regno Unito': 'Londra',
    'Stati Uniti': 'Washington',
    'Spagna': 'Madrid',
    'Paesi Bassi': 'Amsterdam',
    'Corea del Sud': 'Seoul'
}

# %%
assert paesi_capitale_pari(g10) == ['Canada', 'Francia', 'Regno Unito', 'Spagna'], "❌ Lista dei paesi errata"
print("✅ Lista dei paesi con capitale di lunghezza pari corretta")

# %% [markdown]
# ### Esercizio 3
#
# Scrivi una funzione che prenda in input una lista di parole e restituisca una nuova lista contenente solo le parole palindrome.
#
# **Esempio:**
#
# - Input: `['ciao', 'anna', 'radar', 'gatto', 'osso', 'madam']`
# - Output: `['anna', 'radar', 'osso', 'madam']`

# %%
def trova_palindrome(lista_parole):
    return [... for ... if ...]  # completa la condizione parola == parola invertita

# Test
lista_parole = ['ciao', 'anna', 'radar', 'gatto', 'osso', 'madam']
print(trova_palindrome(lista_parole))

# %%
assert trova_palindrome(lista_parole) == ['anna', 'radar', 'osso', 'madam'], "❌ Lista delle parole palindrome errata"
print("✅ Lista delle parole palindrome corretta")
