# %% [markdown]
# # Esercitazione 2
#
# Prendiamo dimestichezza con il dato di Terna sul load.
# - Leggiamo e trasformiamo in datetime Date
# - Visualizziamo ed esploriamo
# - Rinominiamo le colonne
# - Selezioniamo finestre del dato
# - Usiamo Lag e finestra mobile
